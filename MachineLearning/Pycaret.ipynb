# %%
print("Helllo World")
# Out:
# Helllo World

# %%
# loading sample dataset from pycaret dataset module
from pycaret.datasets import get_data
data = get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# import pycaret classification and init setup
from pycaret.classification import *
s = setup(data, target = 'species', session_id = 123)
# Out:
# <style type="text/css">
# #T_5a907_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5a907">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a907_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5a907_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a907_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a907_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5a907_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5a907_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5a907_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5a907_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5a907_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5a907_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_5a907_row3_col1" class="data row3 col1" >Iris-setosa: 0, Iris-versicolor: 1, Iris-virginica: 2</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5a907_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_5a907_row4_col1" class="data row4 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5a907_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_5a907_row5_col1" class="data row5 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5a907_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_5a907_row6_col1" class="data row6 col1" >(105, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5a907_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_5a907_row7_col1" class="data row7 col1" >(45, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5a907_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_5a907_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5a907_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_5a907_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5a907_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_5a907_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5a907_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_5a907_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5a907_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_5a907_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5a907_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_5a907_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5a907_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_5a907_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5a907_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_5a907_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5a907_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_5a907_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5a907_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_5a907_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5a907_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_5a907_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5a907_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5a907_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_5a907_row19_col1" class="data row19 col1" >0bf3</td>
#     </tr>
#   </tbody>
# </table>

# %%
# compare baseline models
best = compare_models()
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         19:06:53
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_63faa th {
#   text-align: left;
# }
# #T_63faa_row0_col0, #T_63faa_row0_col1, #T_63faa_row0_col2, #T_63faa_row0_col3, #T_63faa_row0_col4, #T_63faa_row0_col5, #T_63faa_row0_col6, #T_63faa_row0_col7, #T_63faa_row0_col8, #T_63faa_row1_col0, #T_63faa_row1_col1, #T_63faa_row1_col2, #T_63faa_row1_col3, #T_63faa_row1_col4, #T_63faa_row1_col5, #T_63faa_row1_col6, #T_63faa_row1_col7, #T_63faa_row1_col8, #T_63faa_row2_col0, #T_63faa_row2_col1, #T_63faa_row2_col2, #T_63faa_row2_col3, #T_63faa_row2_col4, #T_63faa_row2_col5, #T_63faa_row2_col6, #T_63faa_row2_col7, #T_63faa_row2_col8, #T_63faa_row3_col0, #T_63faa_row3_col1, #T_63faa_row3_col2, #T_63faa_row3_col3, #T_63faa_row3_col4, #T_63faa_row3_col5, #T_63faa_row3_col6, #T_63faa_row3_col7, #T_63faa_row3_col8, #T_63faa_row4_col0, #T_63faa_row4_col1, #T_63faa_row4_col2, #T_63faa_row4_col3, #T_63faa_row4_col4, #T_63faa_row4_col5, #T_63faa_row4_col6, #T_63faa_row4_col7, #T_63faa_row4_col8, #T_63faa_row5_col0, #T_63faa_row5_col1, #T_63faa_row5_col2, #T_63faa_row5_col3, #T_63faa_row5_col4, #T_63faa_row5_col5, #T_63faa_row5_col6, #T_63faa_row5_col7, #T_63faa_row5_col8, #T_63faa_row6_col0, #T_63faa_row6_col1, #T_63faa_row6_col2, #T_63faa_row6_col3, #T_63faa_row6_col4, #T_63faa_row6_col5, #T_63faa_row6_col6, #T_63faa_row6_col7, #T_63faa_row6_col8, #T_63faa_row7_col0, #T_63faa_row7_col1, #T_63faa_row7_col2, #T_63faa_row7_col3, #T_63faa_row7_col4, #T_63faa_row7_col5, #T_63faa_row7_col6, #T_63faa_row7_col7, #T_63faa_row7_col8, #T_63faa_row8_col0, #T_63faa_row8_col1, #T_63faa_row8_col2, #T_63faa_row8_col3, #T_63faa_row8_col4, #T_63faa_row8_col5, #T_63faa_row8_col6, #T_63faa_row8_col7, #T_63faa_row8_col8, #T_63faa_row9_col0, #T_63faa_row9_col1, #T_63faa_row9_col2, #T_63faa_row9_col3, #T_63faa_row9_col4, #T_63faa_row9_col5, #T_63faa_row9_col6, #T_63faa_row9_col7, #T_63faa_row9_col8, #T_63faa_row10_col0, #T_63faa_row10_col1, #T_63faa_row10_col2, #T_63faa_row10_col3, #T_63faa_row10_col4, #T_63faa_row10_col5, #T_63faa_row10_col6, #T_63faa_row10_col7, #T_63faa_row10_col8, #T_63faa_row11_col0, #T_63faa_row11_col1, #T_63faa_row11_col2, #T_63faa_row11_col3, #T_63faa_row11_col4, #T_63faa_row11_col5, #T_63faa_row11_col6, #T_63faa_row11_col7, #T_63faa_row11_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_63faa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63faa_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_63faa_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_63faa_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_63faa_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_63faa_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_63faa_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_63faa_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_63faa_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_63faa_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63faa_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_63faa_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_63faa_row0_col1" class="data row0 col1" >0.9718</td>
#       <td id="T_63faa_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_63faa_row0_col3" class="data row0 col3" >0.9718</td>
#       <td id="T_63faa_row0_col4" class="data row0 col4" >0.9780</td>
#       <td id="T_63faa_row0_col5" class="data row0 col5" >0.9712</td>
#       <td id="T_63faa_row0_col6" class="data row0 col6" >0.9573</td>
#       <td id="T_63faa_row0_col7" class="data row0 col7" >0.9609</td>
#       <td id="T_63faa_row0_col8" class="data row0 col8" >0.4210</td>
#     </tr>
#     <tr>
#       <th id="T_63faa_level0_row1" class="row_heading level0 row1" >knn</th>
#       <td id="T_63faa_row1_col0" class="data row1 col0" >K Neighbors Classifier</td>
#       <td id="T_63faa_row1_col1" class="data row1 col1" >0.9718</td>
#       <td id="T_63faa_row1_col2" class="data row1 col2" >0.9830</td>
#       <td id="T_63faa_row1_col3" class="data row1 col3" >0.9718</td>
#       <td id="T_63faa_row1_col4" class="data row1 col4" >0.9780</td>
#       <td id="T_63faa_row1_col5" class="data row1 col5" >0.9712</td>
#       <td id="T_63faa_row1_col6" class="data row1 col6" >0.9573</td>
#       <td id="T_63faa_row1_col7" class="data row1 col7" >0.9609</td>
#       <td id="T_63faa_row1_col8" class="data row1 col8" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_63faa_level0_row2" class="row_heading level0 row2" >qda</th>
#       <td id="T_63faa_row2_col0" class="data row2 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_63faa_row2_col1" class="data row2 col1" >0.9718</td>
#       <td id="T_63faa_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_63faa_row2_col3" class="data row2 col3" >0.9718</td>
#       <td id="T_63faa_row2_col4" class="data row2 col4" >0.9780</td>
#       <td id="T_63faa_row2_col5" class="data row2 col5" >0.9712</td>
#       <td id="T_63faa_row2_col6" class="data row2 col6" >0.9573</td>
#       <td id="T_63faa_row2_col7" class="data row2 col7" >0.9609</td>
#       <td id="T_63faa_row2_col8" class="data row2 col8" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_63faa_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_63faa_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_63faa_row3_col1" class="data row3 col1" >0.9718</td>
#       <td id="T_63faa_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_63faa_row3_col3" class="data row3 col3" >0.9718</td>
#       <td id="T_63faa_row3_col4" class="data row3 col4" >0.9780</td>
#       <td id="T_63faa_row3_col5" class="data row3 col5" >0.9712</td>
#       <td id="T_63faa_row3_col6" class="data row3 col6" >0.9573</td>
#       <td id="T_63faa_row3_col7" class="data row3 col7" >0.9609</td>
#       <td id="T_63faa_row3_col8" class="data row3 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_63faa_level0_row4" class="row_heading level0 row4" >nb</th>
#       <td id="T_63faa_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_63faa_row4_col1" class="data row4 col1" >0.9445</td>
#       <td id="T_63faa_row4_col2" class="data row4 col2" >0.9868</td>
#       <td id="T_63faa_row4_col3" class="data row4 col3" >0.9445</td>
#       <td id="T_63faa_row4_col4" class="data row4 col4" >0.9525</td>
#       <td id="T_63faa_row4_col5" class="data row4 col5" >0.9438</td>
#       <td id="T_63faa_row4_col6" class="data row4 col6" >0.9161</td>
#       <td id="T_63faa_row4_col7" class="data row4 col7" >0.9207</td>
#       <td id="T_63faa_row4_col8" class="data row4 col8" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_63faa_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_63faa_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_63faa_row5_col1" class="data row5 col1" >0.9445</td>
#       <td id="T_63faa_row5_col2" class="data row5 col2" >0.9935</td>
#       <td id="T_63faa_row5_col3" class="data row5 col3" >0.9445</td>
#       <td id="T_63faa_row5_col4" class="data row5 col4" >0.9586</td>
#       <td id="T_63faa_row5_col5" class="data row5 col5" >0.9426</td>
#       <td id="T_63faa_row5_col6" class="data row5 col6" >0.9161</td>
#       <td id="T_63faa_row5_col7" class="data row5 col7" >0.9246</td>
#       <td id="T_63faa_row5_col8" class="data row5 col8" >0.0510</td>
#     </tr>
#     <tr>
#       <th id="T_63faa_level0_row6" class="row_heading level0 row6" >gbc</th>
#       <td id="T_63faa_row6_col0" class="data row6 col0" >Gradient Boosting Classifier</td>
#       <td id="T_63faa_row6_col1" class="data row6 col1" >0.9355</td>
#       <td id="T_63faa_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_63faa_row6_col3" class="data row6 col3" >0.9355</td>
#       <td id="T_63faa_row6_col4" class="data row6 col4" >0.9416</td>
#       <td id="T_63faa_row6_col5" class="data row6 col5"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # compare baseline models
# ----> 2 best = compare_models()
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pycaret/utils/generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962     if globals_d[name] is None:
#     963         raise ValueError(message)
# --> 964 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pycaret/classification/functional.py:814, in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#     672 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#     673 def compare_models(
#     674     include: Optional[List[Union[str, Any]]] = None,
#    (...)
#     690     parallel: Optional[ParallelBackend] = None,
#     691 ) -> Union[Any, List[Any]]:
#     692     """
#     693     This function trains and evaluates performance of all estimators available in the
#     694     model library using cross validation. The output of this function is a score grid
#    (...)
#     811     - No models are logged in ``MLFlow`` when ``cross_validation`` parameter is False.
#     812     """
# --> 814     return _CURRENT_EXPERIMENT.compare_models(
#     815         include=include,
#     816         exclude=exclude,
#     817         fold=fold,
#     818         round=round,
#     819         cross_validation=cross_validation,
#     820         sort=sort,
#     821         n_select=n_select,
#     822         budget_time=budget_time,
#     823         turbo=turbo,
#     824         errors=errors,
#     825         fit_kwargs=fit_kwargs,
#     826         groups=groups,
#     827         experiment_custom_tags=experiment_custom_tags,
#     828         probability_threshold=probability_threshold,
#     829         engine=engine,
#     830         verbose=verbose,
#     831         parallel=parallel,
#     832     )
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pycaret/classification/oop.py:1180, in ClassificationExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#    1177         self._set_engine(estimator=estimator, engine=eng, severity="error")
#    1179 try:
# -> 1180     return_values = super().compare_models(
#    1181         include=include,
#    1182         exclude=exclude,
#    1183         fold=fold,
#    1184         round=round,
#    1185         cross_validation=cross_validation,
#    1186         sort=sort,
#    1187         n_select=n_select,
#    1188         budget_time=budget_time,
#    1189         turbo=turbo,
#    1190         errors=errors,
#    1191         fit_kwargs=fit_kwargs,
#    1192         groups=groups,
#    1193         experiment_custom_tags=experiment_custom_tags,
#    1194         verbose=verbose,
#    1195         probability_threshold=probability_threshold,
#    1196         parallel=parallel,
#    1197         caller_params=caller_params,
#    1198     )
#    1199 finally:
#    1200     if engine is not None:
#    1201         # Reset the models back to the default engines
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:794, in _SupervisedExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, parallel, caller_params)
#     791 results_columns_to_ignore = ["Object", "runtime", "cutoff"]
#     793 try:
# --> 794     model, model_fit_time = self._create_model(**create_model_args)
#     795     model_results = self.pull(pop=True)
#     796     assert (
#     797         np.sum(
#     798             model_results.drop(
#    (...)
#     802         != 0.0
#     803     )
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:1533, in _SupervisedExperiment._create_model(self, estimator, fold, round, cross_validation, predict, fit_kwargs, groups, refit, probability_threshold, experiment_custom_tags, verbose, system, add_to_model_list, X_train_data, y_train_data, metrics, display, model_only, return_train_score, error_score, **kwargs)
#    1530         return model, model_fit_time
#    1531     return model
# -> 1533 model, model_fit_time, model_results, _ = self._create_model_with_cv(
#    1534     model=model,
#    1535     data_X=data_X,
#    1536     data_y=data_y,
#    1537     fit_kwargs=fit_kwargs,
#    1538     round=round,
#    1539     cv=cv,
#    1540     groups=groups,
#    1541     metrics=metrics,
#    1542     refit=refit,
#    1543     system=system,
#    1544     display=display,
#    1545     error_score=error_score,
#    1546     return_train_score=return_train_score,
#    1547 )
#    1549 # end runtime
#    1550 runtime_end = time.time()
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:1126, in _SupervisedExperiment._create_model_with_cv(self, model, data_X, data_y, fit_kwargs, round, cv, groups, metrics, refit, system, display, error_score, return_train_score)
#    1124     model_fit_start = time.time()
#    1125     with redirect_output(self.logger):
# -> 1126         scores = cross_validate(
#    1127             pipeline_with_model,
#    1128             data_X,
#    1129             data_y,
#    1130             cv=cv,
#    1131             groups=groups,
#    1132             scoring=metrics_dict,
#    1133             params=fit_kwargs,
#    1134             n_jobs=n_jobs,
#    1135             return_train_score=return_train_score,
#    1136             error_score=error_score,
#    1137         )
#    1139 model_fit_end = time.time()
#    1140 model_fit_time = np.array(model_fit_end - model_fit_start).round(2)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:430, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     427 # We clone the estimator to make sure that all the folds are
#     428 # independent, and that it is pickle-able.
#     429 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 430 results = parallel(
#     431     delayed(_fit_and_score)(
#     432         clone(estimator),
#     433         X,
#     434         y,
#     435         scorer=scorers,
#     436         train=train,
#     437         test=test,
#     438         verbose=verbose,
#     439         parameters=None,
#     440         fit_params=routed_params.estimator.fit,
#     441         score_params=routed_params.scorer.score,
#     442         return_train_score=return_train_score,
#     443         return_times=True,
#     444         return_estimator=return_estimator,
#     445         error_score=error_score,
#     446     )
#     447     for train, test in indices
#     448 )
#     450 _warn_or_raise_about_fit_failures(results, error_score)
#     452 # For callable scoring, the return type is only know after calling. If the
#     453 # return type is a dictionary, the error scores can now be inserted with
#     454 # the correct key.
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/joblib/parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
import kagglehub
import pandas as pd

# Download latest version
path = kagglehub.dataset_download("anishdevedward/loan-approval-dataset")

print("Path to dataset files:", path)

data = pd.read_csv(path + "/loan_approval.csv")
data.head()
# Out:
# Path to dataset files: /home/iadel/.cache/kagglehub/datasets/anishdevedward/loan-approval-dataset/versions/1
#               name              city  income  credit_score  loan_amount  \
# 0     Allison Hill         East Jill  113810           389        39698
# 1     Brandon Hall     New Jamesside   44592           729        15446
# 2     Rhonda Smith      Lake Roberto   33278           584        11189
# 3  Gabrielle Davis  West Melanieview  127196           344        48823
# 4     Valerie Gray         Mariastad   66048           496        47174
#
#    years_employed  points  loan_approved
# 0              27    50.0          False
# 1              28    55.0          False
# 2              13    45.0          False
# 3              29    50.0          False
# 4               4    25.0          False

# %%
data = data.drop(['name'], axis=1)

# %%
exp = ClassificationExperiment()
exp.setup(data = data, target = 'loan_approved', session_id=123)
best = exp.compare_models(
    include = ['lr', 'rf', 'dt', 'nb', 'knn', 'svm']
)
# Out:
# <style type="text/css">
# #T_fd83b_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fd83b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd83b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fd83b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd83b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd83b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fd83b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fd83b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fd83b_row1_col1" class="data row1 col1" >loan_approved</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fd83b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_fd83b_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fd83b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_fd83b_row3_col1" class="data row3 col1" >(2000, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fd83b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_fd83b_row4_col1" class="data row4 col1" >(2000, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fd83b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_fd83b_row5_col1" class="data row5 col1" >(1400, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fd83b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_fd83b_row6_col1" class="data row6 col1" >(600, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fd83b_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_fd83b_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fd83b_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_fd83b_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fd83b_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_fd83b_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fd83b_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_fd83b_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fd83b_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_fd83b_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fd83b_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_fd83b_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fd83b_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_fd83b_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fd83b_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_fd83b_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fd83b_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_fd83b_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fd83b_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_fd83b_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fd83b_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_fd83b_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fd83b_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_fd83b_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_fd83b_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_fd83b_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_fd83b_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_fd83b_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_fd83b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_fd83b_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_fd83b_row21_col1" class="data row21 col1" >6d09</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b40bd th {
#   text-align: left;
# }
# #T_b40bd_row0_col0, #T_b40bd_row1_col0, #T_b40bd_row2_col0, #T_b40bd_row3_col0, #T_b40bd_row3_col1, #T_b40bd_row3_col2, #T_b40bd_row3_col3, #T_b40bd_row3_col4, #T_b40bd_row3_col5, #T_b40bd_row3_col6, #T_b40bd_row3_col7, #T_b40bd_row4_col0, #T_b40bd_row4_col1, #T_b40bd_row4_col2, #T_b40bd_row4_col3, #T_b40bd_row4_col4, #T_b40bd_row4_col5, #T_b40bd_row4_col6, #T_b40bd_row4_col7, #T_b40bd_row5_col0, #T_b40bd_row5_col1, #T_b40bd_row5_col2, #T_b40bd_row5_col3, #T_b40bd_row5_col4, #T_b40bd_row5_col5, #T_b40bd_row5_col6, #T_b40bd_row5_col7 {
#   text-align: left;
# }
# #T_b40bd_row0_col1, #T_b40bd_row0_col2, #T_b40bd_row0_col3, #T_b40bd_row0_col4, #T_b40bd_row0_col5, #T_b40bd_row0_col6, #T_b40bd_row0_col7, #T_b40bd_row1_col1, #T_b40bd_row1_col2, #T_b40bd_row1_col3, #T_b40bd_row1_col4, #T_b40bd_row1_col5, #T_b40bd_row1_col6, #T_b40bd_row1_col7, #T_b40bd_row2_col1, #T_b40bd_row2_col2, #T_b40bd_row2_col3, #T_b40bd_row2_col4, #T_b40bd_row2_col5, #T_b40bd_row2_col6, #T_b40bd_row2_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_b40bd_row0_col8, #T_b40bd_row1_col8, #T_b40bd_row3_col8, #T_b40bd_row4_col8, #T_b40bd_row5_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_b40bd_row2_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_b40bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b40bd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b40bd_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_b40bd_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_b40bd_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_b40bd_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_b40bd_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_b40bd_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_b40bd_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_b40bd_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b40bd_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_b40bd_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_b40bd_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_b40bd_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_b40bd_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_b40bd_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_b40bd_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_b40bd_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_b40bd_row0_col7" class="data row0 col7" >1.0000</td>
#       <td id="T_b40bd_row0_col8" class="data row0 col8" >0.5470</td>
#     </tr>
#     <tr>
#       <th id="T_b40bd_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_b40bd_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_b40bd_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_b40bd_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_b40bd_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_b40bd_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_b40bd_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_b40bd_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_b40bd_row1_col7" class="data row1 col7" >1.0000</td>
#       <td id="T_b40bd_row1_col8" class="data row1 col8" >0.1150</td>
#     </tr>
#     <tr>
#       <th id="T_b40bd_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_b40bd_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_b40bd_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_b40bd_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_b40bd_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_b40bd_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_b40bd_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_b40bd_row2_col6" class="data row2 col6" >1.0000</td>
#       <td id="T_b40bd_row2_col7" class="data row2 col7" >1.0000</td>
#       <td id="T_b40bd_row2_col8" class="data row2 col8" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_b40bd_level0_row3" class="row_heading level0 row3" >nb</th>
#       <td id="T_b40bd_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_b40bd_row3_col1" class="data row3 col1" >0.9607</td>
#       <td id="T_b40bd_row3_col2" class="data row3 col2" >0.9892</td>
#       <td id="T_b40bd_row3_col3" class="data row3 col3" >0.9318</td>
#       <td id="T_b40bd_row3_col4" class="data row3 col4" >0.9781</td>
#       <td id="T_b40bd_row3_col5" class="data row3 col5" >0.9540</td>
#       <td id="T_b40bd_row3_col6" class="data row3 col6" >0.9198</td>
#       <td id="T_b40bd_row3_col7" class="data row3 col7" >0.9211</td>
#       <td id="T_b40bd_row3_col8" class="data row3 col8" >0.0290</td>
#     </tr>
#     <tr>
#       <th id="T_b40bd_level0_row4" class="row_heading level0 row4" >svm</th>
#       <td id="T_b40bd_row4_col0" class="data row4 col0" >SVM - Linear Kernel</td>
#       <td id="T_b40bd_row4_col1" class="data row4 col1" >0.5821</td>
#       <td id="T_b40bd_row4_col2" class="data row4 col2" >0.6620</td>
#       <td id="T_b40bd_row4_col3" class="data row4 col3" >0.3734</td>
#       <td id="T_b40bd_row4_col4" class="data row4 col4" >0.4962</td>
#       <td id="T_b40bd_row4_col5" class="data row4 col5" >0.3548</td>
#       <td id="T_b40bd_row4_col6" class="data row4 col6" >0.1201</td>
#       <td id="T_b40bd_row4_col7" class="data row4 col7" >0.1325</td>
#       <td id="T_b40bd_row4_col8" class="data row4 col8" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_b40bd_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_b40bd_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_b40bd_row5_col1" class="data row5 col1" >0.5693</td>
#       <td id="T_b40bd_row5_col2" class="data row5 col2" >0.6086</td>
#       <td id="T_b40bd_row5_col3" class="data row5 col3" >0.4618</td>
#       <td id="T_b40bd_row5_col4" class="data row5 col4" >0.5109</td>
#       <td id="T_b40bd_row5_col5" class="data row5 col5" >0.4840</td>
#       <td id="T_b40bd_row5_col6" class="data row5 col6" >0.1165</td>
#       <td id="T_b40bd_row5_col7" class="data row5 col7" >0.1173</td>
#       <td id="T_b40bd_row5_col8" class="data row5 col8" >0.0360</td>
#     </tr>
#   </tbody>
# </table>
